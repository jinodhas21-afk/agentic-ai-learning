# %%
import os
from dotenv import load_dotenv
load_dotenv()

openai_api_key=os.getenv("OPENAI_API_KEY")

from langchain_openai import ChatOpenAI
model=ChatOpenAI(model="gpt-4o-mini")

# %%
def story_teller(topic):
    prompt = f"""Write an engaging and educational story about {topic} for beginners. 
            Use simple and clear language to explain basic concepts. 
            Include interesting facts and keep it friendly and encouraging. 
            The story should be around 200-300 words and end with a brief summary of what we learned. 
            Make it perfect for someone just starting to learn about this topic."""
    
    response = model.invoke(prompt).content
    return response

topic = "the solar system"
story = story_teller(topic)
print("Generated Story:\n", story)
# Out:
# Generated Story:
#  **The Journey Through Our Solar System**
#
# Once upon a time, in a vast, sparkling space, there was a magnificent family of planets that danced around a warm, glowing star called the Sun. This star was like a giant campfire in the sky, giving light and warmth to everyone in the family. They all lived in a place called the solar system.
#
# First, let’s meet the closest planet to the Sun: Mercury. Mercury is very small and speedy, whizzing around the Sun in just 88 Earth days! It’s very hot on one side and freezing on the other because it has no atmosphere.
#
# Next, we have Venus, often called Earth’s twin. It's about the same size but shrouded in thick, swirling clouds. These clouds trap heat, making Venus the hottest planet in our solar system!
#
# Our home, Earth, is the third planet. It’s special because it has water, air, and life! We spin on our axes and orbit the Sun, making one full trip in 365 days.
#
# Mars, the fourth planet, is known as the Red Planet because of its rusty color. Scientists think there might have been water there long ago, and they are searching for signs of life!
#
# Jupiter comes next, the largest planet, with a huge storm called the Great Red Spot. It’s like a big whirlpool, spinning for hundreds of years!
#
# Then we have Saturn, famous for its stunning rings made of ice and rock. Beyond it lies Uranus, which spins on its side, making it unique among the planets.
#
# Finally, there’s Neptune, the furthest planet, known for its beautiful blue color and strong winds.
#
# Throughout our journey in the solar system, we learned about the Sun, eight fascinating planets, and how each one is special in its own way. From the small and speedy Mercury to the beautiful rings of Saturn, space is a marvelous place waiting to be explored!

# %% [markdown]
# convert story into audio

# %%
from gtts import gTTS # Google Text-to-Speech
from IPython.display import Audio # To play audio in Jupyter notebooks
import io # For in-memory byte streams

tts=gTTS(text=story,lang='en')

audio_bytes = io.BytesIO()
tts.write_to_fp(audio_bytes)
audio_bytes.seek(0)  # Move to the beginning of the BytesIO stream

Audio(audio_bytes.read(), autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
